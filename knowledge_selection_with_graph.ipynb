# %%
import os
import argparse
from ruamel.yaml import YAML
from pathlib import Path
import utils
import json
from vqaTools.vqa import VQA
import datetime
import csv
from dataset.utils import vqa_eval, save_result, load_json
import time
# Out:
# /home/hsh/anaconda3/envs/img2llm/lib/python3.10/site-packages/torch/__init__.py:747: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /opt/conda/conda-bld/pytorch_1712608935911/work/torch/csrc/tensor/python_tensor.cpp:431.)
#   _C._set_default_tensor_type(t)
# [nltk_data] Downloading package wordnet to /home/hsh/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/hsh/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /home/hsh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import torch
import torch.backends.cudnn as cudnn
from accelerate import init_empty_weights, dispatch_model, infer_auto_device_map, load_checkpoint_and_dispatch
from transformers import AutoConfig, AutoModelForCausalLM, AutoTokenizer, AutoModelForSeq2SeqLM
from huggingface_hub import snapshot_download
import en_core_web_sm
nlp = en_core_web_sm.load()
os.environ["TOKENIZERS_PARALLELISM"] = "true"

# %%
def update(params, args):
    params['min_answer_length'] = args.min_answer_length
    params['max_answer_length'] = args.max_answer_length
    params['model_selection'] = args.model_selection
    params['dist_selection'] = args.dist_selection

    params['dataset'] = args.dataset
    params['split_seed'] = args.split_seed
    params['num_sample'] = args.num_sample
    params['output_dir'] = args.output_dir
    params['test_server'] = args.test_server

    params['num_caps_per_img'] = args.num_caps_per_img
    params['num_question_per_img'] = args.num_question_per_img
    params['caption_file'] = args.caption_file

    params['question_file'] = args.question_file
    params['question_ppl_file'] = args.question_ppl_file
    params['ans_dict_file'] = args.ans_dict_file

    params['question_type'] = args.question_type

    params['random_question'] = args.random_question
    params['result_tag'] = args.result_tag
    params['evaluate_direct'] = args.evaluate_direct
    params['resume'] = args.resume

    return params

# %%
def create_cap_dic(caption_data):
    cap = []
    que_id = []
    for i in caption_data:
        que_id.append(i['question_id'])
        if isinstance(i['caption'], list):
            total_caption_list = []
            for ctx_id, cap_ in enumerate(i['caption'][:100]):
                total_caption_list.append((cap_.capitalize().strip()).rstrip()+".")
            cap.append(total_caption_list)
        else:
            raise NotImplementedError()
    caption_dict = dict(zip(que_id, cap))
    return caption_dict

# %%
def create_ans_to_cap_dic(ans_to_cap_data):
    que_id = []
    ans_dicts = []

    for i in ans_to_cap_data:
        que_id.append(i['question_id'])
        if 'ans_to_cap_dict' not in i.keys():
            key = 'tag'
        else:
            key = 'ans_to_cap_dict'
        if isinstance(i[key], dict):
                ans_dicts.append(i[key])
        else:
            raise NotImplementedError()
    ans_to_cap_dicts = dict(zip(que_id, ans_dicts))
    return ans_to_cap_dicts

# %%
def create_generated_question_dic(question_data):
    que_id = []
    syn_question = []
    syn_answer = []
    que_id = []
    ans_dicts = []

    for i in question_data:
        que_id.append(i['question_id'])
        if isinstance(i['question'], list):
            total_syn_question_list = []
            for ctx_id, syn_question_ in enumerate(i['question']):
                total_syn_question_list.append(syn_question_.capitalize().strip().rstrip())
            syn_question.append(total_syn_question_list)
        else:
            raise NotImplementedError()
        if isinstance(i['answer'], list):
            total_syn_answer_list = []
            for ctx_id, syn_answer_ in enumerate(i['answer']):
                total_syn_answer_list.append(syn_answer_.capitalize().strip().rstrip())
            syn_answer.append(total_syn_answer_list)
        else:
            raise NotImplementedError()
    syn_question_dict = dict(zip(que_id, syn_question))
    syn_answer_dict = dict(zip(que_id, syn_answer))

    return syn_question_dict,syn_answer_dict

# %%
# os.environ["NCCL_ASYNC_ERROR_HANDLING"] = "1" #this work together with dist barrier timeout
parser = argparse.ArgumentParser()
parser.add_argument('--config', default='./configs/OKVQA_caption.yaml')
parser.add_argument('--caption_file', default='/home/mingyu/projects/Img2Prompt/caption_question_files/okvqa_caption.json')
parser.add_argument('--question_file', default='/home/mingyu/projects/Img2Prompt/caption_question_files/okvqa_question.json')
parser.add_argument('--question_ppl_file', default=None)
parser.add_argument('--ans_dict_file', default='/home/mingyu/projects/Img2Prompt/caption_question_files/okvqa_ans_to_cap_dict.json')
parser.add_argument('--question_type', default='g_q', type=str)

parser.add_argument('--output_dir', default='output/VQA_caption')
parser.add_argument('--resume', action='store_true')

parser.add_argument('--evaluate_direct', action='store_true')

parser.add_argument('--evaluate', action='store_true')
parser.add_argument('--vqa_eval', action='store_true')

parser.add_argument('--device', default='cuda')
parser.add_argument('--seed', default=42, type=int)
parser.add_argument('--split_seed', default=0, type=int)
parser.add_argument('--num_sample', default=16, type=int)
parser.add_argument('--ensemble', default=1, type=int)
parser.add_argument('--random_question', action='store_true')
parser.add_argument('--test_server', action='store_true')



parser.add_argument('--model_selection', default='opt-6.7b', type=str)
parser.add_argument('--dist_selection', default='hugging', type=str)
parser.add_argument('--select_cap', action='store_true')

parser.add_argument('--dataset', default='vqa_caption', type=str)
parser.add_argument('--result_tag', default='', type=str)

parser.add_argument('--batch_size_test', default=64, type=int)


parser.add_argument('--num_caps_per_img', default=30, type=int)
parser.add_argument('--num_question_per_img', default=30, type=int)

parser.add_argument('--min_answer_length', default=1, type=int,
                    help='min answer length during inference (generate); '
                         'None  == self.model.config.min_length (0 for t0)')
parser.add_argument('--max_answer_length', default=10, type=int,
                    help='max answer length during inference (generate); '
                         'None  == self.model.config.max_length (20 for t0)')
args = parser.parse_args(args=[])

# %%
yaml = YAML(typ='rt')

config = yaml.load(open(args.config, 'r'))
# config = yaml.load(open(args.config, 'r'), Loader=yaml.Loader)
config = update(config, args)
args.result_dir = os.path.join(args.output_dir, 'result')

Path(args.output_dir).mkdir(parents=True, exist_ok=True)
Path(args.result_dir).mkdir(parents=True, exist_ok=True)

yaml.dump(config, open(os.path.join(args.output_dir, 'config.yaml'), 'w'))
logger, writer = utils.setup_default_logging(args)

# %%
#### Dataset ####
print("Creating vqa datasets")
test_data = []
for f in config['test_file']:
    test_data = json.load(open(f, 'r'))

caption_data = json.load(open(config['caption_file'], 'r'))
quesID_to_cap_dict = create_cap_dic(caption_data)

question_data = json.load(open(config['question_file'], 'r'))
quesID_to_ques_data,syn_answer_dict = create_generated_question_dic(question_data)  # synthetic question, synthetic answer

ans_dict_data = json.load(open(config['ans_dict_file'], 'r'))
ans_to_cap_dicts = create_ans_to_cap_dic(ans_dict_data)
# Out:
# Creating vqa datasets

# %%
if config['val_ann_path']:
    vqa = VQA(config['val_ann_path'], config['val_ques_path'])


result_filename = config['result_tag']+'_'+config['dataset']+'_'+config['model_selection']+'_'+config['dist_selection'] + 'caps'+str(config['num_caps_per_img']) +'_question'+ str(config['num_question_per_img'])+'_questiontype'+'_'+config['question_type']
start_time = time.time()
# Out:
# loading VQA annotations and questions into memory...
# creating index...
# index created!

# %%
metric_logger = utils.MetricLogger(delimiter="  ", logger=logger)
header = 'Generate VQA test result:'
print_freq = 1000
result = []
tested_quesId_dict = {}
# print(result)
for tested_dict in result:
    # print(result)
    if tested_dict['answer'] is not None:
        tested_quesId_dict[tested_dict['question_id']] = 1
# print(test_data)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from transformers import AutoConfig, AutoModelForCausalLM, AutoTokenizer, AutoModelForSeq2SeqLM
from huggingface_hub import snapshot_download, notebook_login
import huggingface_hub
import os

import networkx as nx
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer, util

# %%
# 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
os.environ["CUDA_VISIBLE_DEVICES"]= "0"

# 모델 로드
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
from tqdm import tqdm

# %%
for n, per_test_data in enumerate(metric_logger.log_every(test_data, print_freq, header)):

    # if n <= 1340: continue
    # print(n)
    # break
    kb_score_dict = {}
    question = per_test_data['question'].lower().strip()
    question_id = per_test_data['question_id']
    # print(question_id, question)
    
    selected_kb_list = []
    
    file_path = f"./knowledge_files/okvqa_pagerank_kb/{question_id}.json"
    if os.path.exists(file_path):
        print(f"File {file_path} exists.")
        continue
    else:
        # with open(f"../cluster_generated_kb/{question_id}.json", "r") as f:
        with open(f"/home/hsh/DKSVQA-main/knowledge_files/okvqa_cluster_generated_kb/{question_id}.json", "r") as f:
            kb = json.load(f)

        kb = list(set(kb))        
        
        question_embedding = model.encode(question, convert_to_tensor=True)
        knowledge_embeddings = model.encode(kb, convert_to_tensor=True)
        
        cosine_scores = util.pytorch_cos_sim(question_embedding, knowledge_embeddings)
        
        G = nx.Graph()
        
        G.add_node("Question", label=question)
        # Knowledge 문장 노드 및 엣지 추가 (유사도 임계값 설정)
        threshold = 0.5  # 유사도 임계값
        for idx, sentence in enumerate(kb):
            similarity = cosine_scores[0][idx].item()
            if similarity >= threshold:
                G.add_node(f"Knowledge_{idx}", label=sentence)
                G.add_edge("Question", f"Knowledge_{idx}", weight=similarity)
                
        for i in range(len(kb)):
            for j in range(i + 1, len(kb)):
                # 각 Knowledge 문장들 간의 유사도 계산
                similarity = util.pytorch_cos_sim(knowledge_embeddings[i], knowledge_embeddings[j]).item()
                if similarity >= threshold:  # 유사도 임계값 설정
                    G.add_edge(f"Knowledge_{i}", f"Knowledge_{j}", weight=similarity)
        
        # connected_nodes = []  # Question과 연결된 Knowledge 문장 인덱스 저장
        # for idx, sentence in enumerate(kb):
        #     similarity = cosine_scores[0][idx].item()
        #     if similarity >= threshold:
        #         node_name = f"Knowledge_{idx}"
        #         G.add_node(node_name, label=sentence)
        #         G.add_edge("Question", node_name, weight=similarity)
        #         connected_nodes.append(idx)  # 연결된 노드 인덱스 저장

        # # Step 4: Question과 연결된 Knowledge 문장들 간의 유사도 계산 및 엣지 추가
        # for i in range(len(connected_nodes)):
        #     for j in range(i + 1, len(connected_nodes)):
        #         idx_i = connected_nodes[i]
        #         idx_j = connected_nodes[j]
        
        #         # 연결된 Knowledge 문장들 간의 유사도 계산
        #         similarity = util.pytorch_cos_sim(knowledge_embeddings[idx_i], knowledge_embeddings[idx_j]).item()
        #         if similarity >= threshold:  # 임계값 이상인 경우에만 엣지 추가
        #             G.add_edge(f"Knowledge_{idx_i}", f"Knowledge_{idx_j}", weight=similarity)
        
        # 중심성 계산
        degree_centrality = nx.degree_centrality(G)
        betweenness_centrality = nx.betweenness_centrality(G)
        pagerank = nx.pagerank(G, alpha=0.85)
        
        # Step 5: 가장 중요한 Knowledge 문장 선택 (PageRank 기준)
        sorted_pagerank = sorted(pagerank.items(), key=lambda x: x[1], reverse=True)
        
        
        # 시각화 코드 (나중에 필요시 참고!) ============================================================================================
        # print("=== 중요도 순으로 정렬된 문장들 (PageRank 기준) ===")
        # print(f'question: {question}')
        # for node, score in sorted_pagerank:
        #     if node.startswith("Knowledge"):
        #         idx = int(node.split("_")[1])
        #         print(f"문장: {kb[idx]} | 점수: {score:.4f}")
        
    
        # # Step 6: 그래프 시각화
        # plt.figure(figsize=(12, 8))
        # pos = nx.spring_layout(G, seed=42)  # 그래프 레이아웃

        # # 노드 라벨 추출
        # labels = nx.get_node_attributes(G, 'label')

        # # 노드와 엣지 시각화
        # nx.draw(G, pos, with_labels=True, labels=labels, node_size=3000, node_color="skyblue", font_size=10, font_color="black")
        # edge_labels = nx.get_edge_attributes(G, 'weight')
        # nx.draw_networkx_edge_labels(G, pos, edge_labels={(u, v): f"{d['weight']:.2f}" for u, v, d in G.edges(data=True)})

        # plt.title("Question-Knowledge Sentence Graph with Centrality")
        # plt.show()
        # ==============================================================================================================================
        
        for node, score in sorted_pagerank:
            if node.startswith("Knowledge"):
                idx = int(node.split("_")[1]) # kb[idx]
                selected_kb_list.append(kb[idx])
        
        # if len(selected_kb_list) != 3:
        #     print(len(selected_kb_list))
        
        # with open(f"../okvqa_selected_kb/{question_id}.json", "w") as f:
        with open(f"./knowledge_files/okvqa_pagerank_kb/{question_id}.json", "w") as f:
            json.dump(selected_kb_list, f)
# Out:
# File ./knowledge_files/okvqa_pagerank_kb/2971475.json exists.
# 2024-12-18 04:31:16,335 - INFO - train -   Generate VQA test result:  [   0/5046]  eta: 0:00:01    time: 0.0002  data: 0.0000  max mem: 87
# File ./knowledge_files/okvqa_pagerank_kb/3397615.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3575865.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/949225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2076115.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5723996.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5759705.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3045575.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2183655.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2863135.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/299845.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/115115.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3234605.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5169165.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/217115.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3133865.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4026395.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4575845.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4883775.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3017535.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1833195.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3970635.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4976605.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2357845.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3190735.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5144685.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4371265.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5182875.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3804595.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5002005.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3156685.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3736625.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4293695.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4273415.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3938365.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/179845.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3268375.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2780325.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1110325.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5096415.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3413095.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1121605.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2645405.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1089825.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2929715.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1902045.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3774865.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1282805.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1318415.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1305165.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2845485.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5069455.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4247445.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5681485.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/857725.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1396845.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4732085.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3030245.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5342525.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1649245.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1197855.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/511915.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1943135.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3325125.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3763585.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3959785.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2162545.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2913705.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3304055.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/505145.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5666345.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1569995.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4535205.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3282845.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2335535.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3589765.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1050405.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5379826.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2352215.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4854245.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2864225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5192715.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1449855.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5605665.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3430685.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1527025.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1603935.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2597615.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3883985.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4071465.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5525735.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1000065.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5685555.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2873285.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5649115.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4471175.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3294555.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1365725.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5775245.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2707535.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2231575.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3087645.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2940305.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2741565.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5522215.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4684875.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5156125.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2085245.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1970975.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2365425.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1041195.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2264595.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2749575.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1341195.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1708525.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1667045.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4100045.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/639735.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/979885.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4959965.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2980515.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2921885.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5735275.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5461715.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3989925.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3159865.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/418675.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1708495.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1803295.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5341945.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/195795.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2769645.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5407405.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/243965.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5132835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2993555.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3848225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5683585.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/357265.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2293835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2542775.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3404725.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1008115.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3591265.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3064155.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/584726.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4258485.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/586905.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1547215.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1690895.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3884225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3832295.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4246685.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3817095.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2086495.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3955315.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1726865.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4087365.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2816015.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5267215.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/134905.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1474155.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/307195.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4086215.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2142445.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5490485.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2947765.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2966345.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2122885.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2705545.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4974395.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5814515.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2368845.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2261615.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/310165.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4720345.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5817025.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/848895.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1932615.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4923495.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3130935.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/675325.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1390725.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1115485.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1731385.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1915856.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3670825.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1452955.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2406055.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2727385.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1378035.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1095325.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4516835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4509935.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5431125.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5445745.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2926175.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4831795.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1996815.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3114655.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3123415.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/480675.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4642635.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5007175.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4591645.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4357425.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5747855.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3896845.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5143765.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/799555.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3798425.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/433455.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5793375.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5051325.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1843215.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4606215.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4670225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3023885.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3453855.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1897825.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/358945.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/589105.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4347635.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5692515.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/216395.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3588835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2678375.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4358075.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5041015.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5592705.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4123495.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1918465.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/995815.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/89815.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5071715.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4648575.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/539655.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3359815.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4133205.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4750535.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4175885.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1099075.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1184065.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1552915.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3898695.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3707015.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1240185.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4281785.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3328525.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5462195.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5020015.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/802195.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/71085.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1631185.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5018985.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4854065.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5287315.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3975875.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/570865.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1644975.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2972695.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3050505.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3921745.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3859185.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1398715.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1083155.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4576835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1678185.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2966845.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2184045.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4313065.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3836215.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3718905.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4483205.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1379505.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3587635.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4347465.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2866715.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3157445.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/560915.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5070815.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5298505.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1828405.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/190365.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5283115.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/995925.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2302265.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2023435.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1428155.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4943455.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2710255.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4191585.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/784265.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4468125.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5464635.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4750435.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1629525.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1171705.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4843315.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/485555.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1406515.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3837775.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4219025.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5374275.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4244325.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1903135.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3221065.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5211425.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1330345.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3766255.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4601455.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3334345.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4193715.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1925355.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4948555.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5355195.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5673835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4907395.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3156105.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4422235.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1706305.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2564705.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3866375.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5352535.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/550025.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1656755.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5396045.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4937995.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2934525.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3798005.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2245675.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3530015.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4642965.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4672505.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5693145.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2281225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1888625.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/703535.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2887995.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/153865.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/425.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5186155.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1648485.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/511745.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2111925.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4515595.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3329405.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3123855.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1069125.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/800225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2857425.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4712265.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1174325.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1174415.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4943285.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4658355.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1169515.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4573945.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3486315.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/265075.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4951465.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3281115.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4207755.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/115525.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2575575.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4488105.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3017995.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3732665.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3883745.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1350765.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4409375.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1638525.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4893465.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5541425.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/246105.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1967155.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3008145.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/806665.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3835135.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3257205.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4630375.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2025625.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1745035.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1129155.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/991195.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/698845.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4010035.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/736345.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3441005.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4749345.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3419335.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5593885.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/980485.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/917515.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3502305.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/752835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3972785.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1631555.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4986105.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4242705.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/169585.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/289985.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4350695.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4637815.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3982365.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2774405.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5815575.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5764615.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4359575.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3187015.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1256735.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2986335.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1812965.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3524785.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3965435.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2513795.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1653365.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1964625.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4178045.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2414535.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2182245.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2706725.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3122785.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4634065.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5135555.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1559125.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1362505.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1499095.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5130985.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2994095.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3434245.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4499815.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1128185.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1610475.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4226225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3118465.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4242085.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2444875.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2517415.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4497085.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1340015.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1153005.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1995165.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5651985.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4987585.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5643175.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4490735.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1525435.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5521885.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4088185.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4161845.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/381185.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1927015.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4410835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/844985.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2295295.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3186715.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5267065.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/264135.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2302205.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2808105.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3898435.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2799405.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2546095.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5610885.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5440945.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5543575.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4638655.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5393265.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/766195.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/581745.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/351605.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1778385.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/524705.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5101385.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1611125.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5187215.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5330325.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/333455.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3968215.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3287805.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5304665.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1828345.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/113645.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3874295.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5723995.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3312425.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2100995.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3036115.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/635655.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5700395.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/300495.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5046705.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2935745.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5253715.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3030065.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3981385.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/468895.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3709805.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5113635.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1607615.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/516055.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4306525.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1209775.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4288125.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/508295.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/13745.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3086775.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2934255.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2056475.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1030175.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4357835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1345425.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1326835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2158125.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/894595.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5758225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2213035.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1736935.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2805365.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2560915.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/206085.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2029265.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1960855.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3004085.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5813945.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/444675.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5742565.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1760075.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4632835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3418385.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/245605.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4983815.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5416645.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2341695.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1962445.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5163415.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3285.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/561585.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2434425.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/995435.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3946595.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2264965.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4531665.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1675445.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5493005.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/999965.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3494865.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/94505.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5474935.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5314955.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3855865.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4437845.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4340895.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3058005.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1121105.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1063305.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4029315.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1006245.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1082445.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5087315.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/166065.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/603635.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3160075.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/860015.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3680805.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4196245.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3239255.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3719455.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3078475.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2968865.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1652255.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4952885.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2934745.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2651255.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/380315.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4227295.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5782035.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1267015.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/586475.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4767705.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3548295.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5692895.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/229695.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4007195.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2454815.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4930225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1168455.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/6615.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3652775.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3678915.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5153035.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/679665.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4342615.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4903385.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2540015.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4398405.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2715655.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/705285.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1746905.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/727645.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4431015.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3144935.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/895495.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5361835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4570785.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4091165.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5306315.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1390945.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2733295.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3448885.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1504105.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4073555.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4339715.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3784675.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4902795.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2583225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/943555.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3151915.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4099645.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5787105.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4486005.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3459795.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5314335.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1879015.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3649735.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2853255.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2935055.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2852915.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5625815.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3658865.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1551255.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/234115.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3174105.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/789795.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1063385.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/376165.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/868355.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4794775.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2608085.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1137565.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/606775.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3611535.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3321595.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4970675.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1571705.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/429445.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4295985.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4606525.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2117225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5244595.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1400685.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3170625.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5577095.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/419455.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5286045.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/901555.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5590625.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1994425.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3814165.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1675725.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/287195.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2494045.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3300515.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2987325.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1449325.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1144205.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5724955.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4122475.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3920485.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/432615.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/844545.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3145045.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1683755.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/889835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5242165.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/112915.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4812125.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5218045.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4462075.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2026525.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3453295.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1414535.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5473095.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4681615.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4780935.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4186235.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3313665.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3973095.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/846436.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5662775.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3501325.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4133775.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3979035.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4601295.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2569735.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3165965.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2954265.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4713425.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4968015.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/540915.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3076585.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3324615.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2145195.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4704235.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3891295.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/487865.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5593125.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2495065.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/968325.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/440655.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3196475.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/449505.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2450945.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4989715.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4919655.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1067935.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5690705.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/781075.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3732555.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/534105.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/926045.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1311525.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/698275.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2099895.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5004205.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2399925.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3313115.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2382635.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1483195.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/784955.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2793435.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1973985.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5785915.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2426445.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2042895.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3586245.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/457105.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2010045.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2092395.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2887695.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2926395.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4012495.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5113335.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5807575.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5780925.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3986375.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2757445.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4956815.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2682295.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1792295.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/504825.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4297545.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1927555.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3168795.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4838975.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/87715.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5770775.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5439925.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5375485.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2285515.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5064415.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2521015.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1984775.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1515165.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4101955.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3494895.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5475195.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4208275.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3940025.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4729305.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4846045.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4202295.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1934805.json exists.
# ...
# File ./knowledge_files/okvqa_pagerank_kb/2590975.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/133485.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/365285.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5771615.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2425235.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5058915.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2644895.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1838335.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2819765.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/597435.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/908915.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/888465.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2683965.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4490315.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3677715.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3358335.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/51055.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1699365.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2649925.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2241185.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2256035.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/241125.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4372845.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3793765.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2407835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1592625.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5122405.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4396515.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3740515.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3853775.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/23885.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3381055.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3903225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4594495.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1533435.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/931405.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/468595.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2369965.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3024985.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/995535.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/366785.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1833875.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1892265.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4344865.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/376755.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1380835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5178895.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/40115.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4825895.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/937255.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1641795.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1485495.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3647435.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4315575.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5427825.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/460115.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/72815.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5061375.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2687705.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/977905.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3040995.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/381865.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5403545.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1366805.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4690305.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/815125.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/415075.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4543145.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4568165.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3061355.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/494735.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1186255.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1662595.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1424545.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3917745.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4415355.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1090555.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1706385.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4522635.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3282005.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2764135.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4011235.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4327325.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/918395.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1491975.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1194765.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2936255.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4488375.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4454335.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2116755.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2237395.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2952695.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/513045.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2525495.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1330615.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5583885.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5723035.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5059335.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2489185.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5167505.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4305465.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2295995.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1579555.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3034095.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/338355.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3256905.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4714465.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3678765.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4725305.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2235545.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/17995.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2767195.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2370605.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5743505.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4327245.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2788905.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3635815.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/623555.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3174245.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1197525.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/795895.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4300965.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4355765.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4747115.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1201575.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2052225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4572265.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2804135.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4481815.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1857745.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4293865.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5451145.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1061935.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2177835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/873565.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3240085.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2138095.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4150165.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1542225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4837235.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3695335.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1228515.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5075755.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/288745.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1450615.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1153635.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1601045.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/671225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2460775.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3102025.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4879255.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1482725.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/497315.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3211765.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1647795.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3722495.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3241895.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/327775.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2955645.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5179385.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2234665.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1501295.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3518875.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1132715.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5409325.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3063835.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5039385.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1199645.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2441675.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3214765.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3652175.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4327965.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3770915.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/348205.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4205465.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2058545.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1173375.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2032145.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1586285.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5730725.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1548545.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4247765.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/237745.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4568335.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4247995.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3272255.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1884475.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3679055.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3941995.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/110995.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5526105.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1255395.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1696485.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/75665.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/996475.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1567275.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5234705.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5659625.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/846935.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3900485.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2138305.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/120475.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3100355.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4258745.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5507845.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5563455.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4129165.json exists.
# 2024-12-18 04:31:16,381 - INFO - train -   Generate VQA test result:  [5000/5046]  eta: 0:00:00    time: 0.0000  data: 0.0000  max mem: 87
# File ./knowledge_files/okvqa_pagerank_kb/1118405.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1261375.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/709435.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1904235.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3810605.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/351955.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/269425.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1115905.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3686795.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3911875.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5243825.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1589525.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1931225.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1098735.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4322395.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5071475.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1921685.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/169035.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5671975.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3392455.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5393905.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/345675.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2799945.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1081295.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3815635.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4572175.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1275765.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4741645.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4675935.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3844865.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1621445.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5318155.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/510285.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2257515.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1160175.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5369335.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1247595.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1762265.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/2094805.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4984625.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/101235.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/4917845.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/3629415.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/1105875.json exists.
# File ./knowledge_files/okvqa_pagerank_kb/5818295.json exists.
# 2024-12-18 04:31:16,383 - INFO - train -   Generate VQA test result:  [5045/5046]  eta: 0:00:00    time: 0.0000  data: 0.0000  max mem: 87
# 2024-12-18 04:31:16,383 - INFO - train -   Generate VQA test result: Total time: 0:00:00 (0.0000 s / it)
